# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
#import packages needed
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
#get the table from html website
happiness_rank = pd.read_html('https://worldpopulationreview.com/state-rankings/happiest-states')[0]

# %%
#view the dataframe from the website for happiest states data 
happiness_rank
# Out:
#              State  Total Score  Emotional & Physical Well Being  \
# 0           Hawaii        68.27                                1
# 1             Utah        67.84                               18
# 2        Minnesota        67.26                                2
# 3     North Dakota        65.62                                6
# 4       California        63.14                                4
# 5            Idaho        63.09                               24
# 6         Maryland        61.78                                7
# 7             Iowa        61.07                                8
# 8     South Dakota        60.80                               14
# 9         Nebraska        59.11                               10
# 10       Wisconsin        58.87                               16
# 11     Connecticut        58.24                                9
# 12      New Jersey        58.10                                3
# ...

# %%
happiness_rank.shape
# Out:
# (50, 5)

# %% [markdown]
# The table from the html has 50 rows and 5 columns.

# %%
#import overdose death data: 
death_rates = pd.read_csv(' Opioidsdeath.csv')
death_rates.shape
# Out:
# (52, 3)

# %%
death_rates
# Out:
#                 Location  Opioid Overdose Death Rate (Age-Adjusted)  \
# 0                Alabama                                        8.9
# 1                 Alaska                                       10.9
# 2                Arizona                                       18.4
# 3               Arkansas                                        7.0
# 4             California                                        7.9
# 5               Colorado                                       10.6
# 6            Connecticut                                       31.7
# 7               Delaware                                       43.0
# 8   District of Columbia                                       33.7
# 9                Florida                                       18.7
# 10               Georgia                                        8.2
# 11                Hawaii                                        3.5
# 12                 Idaho                                        7.6
# ...

# %% [markdown]
# The table from csv about overdose death rate by state is 52 rows and 3 columns.

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
#use nunique function to identify the number of unique values in each column 
happiness_rank.nunique()
# Out:
# State                              50
# Total Score                        49
# Emotional & Physical Well Being    50
# Work Environment                   50
# Community & Environment            50
# dtype: int64

# %% [markdown]
# Because the data is a ranking of each state among each category, I expected that the data would be different for each, but I was intrigued to see that two states did have a tie for their total score. I analzyed this below. Please note that there is 50 unique values for state and then the three categories that went into total score creation (emotional and physical well being, work environment, and community & environment)

# %%
duplicate = happiness_rank[happiness_rank.duplicated('Total Score')]

# %%
duplicate
# Out:
#        State  Total Score  Emotional & Physical Well Being  Work Environment  \
# 14  New York        57.35                                5                42
#
#     Community & Environment
# 14                       39

# %% [markdown]
# New York (14) and Virgina (13) are tied with a total score of 57.35

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
happiness_rank.duplicated(subset=None, keep='first')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
test = happiness_rank[happiness_rank.duplicated()]

# %%
death_rates.duplicated()[0]
#this tests by columns
# Out:
# False

# %%
death_rates.duplicated()[1]
# Out:
# False

# %%
death_rates.duplicated()[2]
# Out:
# False

# %% [markdown]
# Neither data set shows a column with data redundancy. The code didnt find any redundancy in any of the columns of the data set. I use the duplicate function to study this.

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
#it makes most sense to do a hsitogram of total score columnn considering all other columns are just rankings 1-50.

# %%
happiness_rank.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f333540f0>,
# ...
#       dtype=object)

# %% [markdown]
# The above proves Total score is the only one with distribute variance so I will examine it closer below

# %%
happiness_rank['Total Score'].hist()

# %% [markdown]
# Majority of the scores fall in the 50 - 60 range for total score on happiness scale.

# %%
death_rates['Opioid Overdose Death Rate (Age-Adjusted)'].hist()

# %% [markdown]
# Majority of the scores fall in the 50 - 60 range for total score on happiness scale.

# %%
top_death = death_rates.nlargest(10,['All Drug Overdose Death Rate (Age-Adjusted)'])
top_death
# Out:
#                 Location  Opioid Overdose Death Rate (Age-Adjusted)  \
# 48         West Virginia                                       41.4
# 7               Delaware                                       43.0
# 8   District of Columbia                                       33.7
# 35                  Ohio                                       31.5
# 20              Maryland                                       34.0
# 38          Pennsylvania                                       25.1
# 6            Connecticut                                       31.7
# 17              Kentucky                                       24.6
# 21         Massachusetts                                       28.9
# 29         New Hampshire                                       29.1
#
#     All Drug Overdose Death Rate (Age-Adjusted)
# 48                                         52.8
# 7                                          48.0
# 8                                          43.2
# ...

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
##compare the least happy states to the states with highest incidence of drug overose per 100,000 in the population 
top_death = death_rates.nlargest(10,['All Drug Overdose Death Rate (Age-Adjusted)'])
low_score = happiness_rank.nsmallest(10,['Total Score'])

plot1 = top_death.plot.bar(x ='Location')
plot2 = low_score.plot.bar(x = 'State', y = 'Total Score')

# %% [markdown]
# Something I noticed that I shared with the class was that both West Virginia and Kentucky appear for 10 ten most overdoses AND lowest total happiness scores. I find this connection interesting and I look forward to doing more correlation studies between this data, and also studying the connection between naloxone distribution and overdose rates. I am also curious about the data regarding access to treatment, I may add this variable in to my report as well.

# %% [markdown]
# I noticed another classmate study happiness data and this was insightful to me as well.

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week13_assignment_2.ipynb
    # !git commit -a -m "Submitting the week 12 programming assignment"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
